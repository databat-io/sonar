# %%
# Get 'em imports
from ble.models import Device, ScanRecord
from analytics.models import BleReport
from datetime import datetime, timedelta
from django.conf import settings
from django.utils import timezone
from django_pandas.io import read_frame
import plotly.express as px

# %%
# Define some variables

# Look at records for the last seven days
cut_off = timezone.now() - timedelta(days=7)

# %%
# Get the top 10 devices
qs = Device.objects.filter(
    device_fingerprint__isnull=False,
    seen_last__gte=cut_off
).exclude(device_fingerprint__exact='').order_by('-seen_counter')[:10]

# Generate a Pandas dataframe
df = read_frame(qs, fieldnames=['device_fingerprint', 'device_manufacturer', 'seen_counter', 'seen_last', 'ignore'])
df
# Out:
#                                   device_fingerprint  \
# 0  10a4c6538fe9037cae6bea5069e98240651922c21e78d8...
# 1  30ee10cd6ccccbde389363193a907522b5a9047a630428...
# 2  42b04e17dc95e7ae86987795f23b553d2a2104aa57c8dc...
# 3  4a3a3bd871e5b64359c3eef6bc2bd825a0f8c0c6eb659a...
# 4  13ada7172958af1831cf2ace612e776d6ce5802e98bf2a...
# 5  fbfc713d50dce671f3457fd3292a81c62c53d9fc20666f...
# 6  fbfc713d50dce671f3457fd3292a81c62c53d9fc20666f...
# 7  fbfc713d50dce671f3457fd3292a81c62c53d9fc20666f...
# 8  fbfc713d50dce671f3457fd3292a81c62c53d9fc20666f...
# 9  fbfc713d50dce671f3457fd3292a81c62c53d9fc20666f...
#
#             device_manufacturer  seen_counter  \
# 0  Samsung Electronics Co. Ltd.         23185
# 1               SiRF Technology         22708
# 2  Samsung Electronics Co. Ltd.         22366
# 3                       Unknown         22271
# 4  Samsung Electronics Co. Ltd.         22039
# 5                       Unknown         19821
# 6                       Unknown         19378
# 7                       Unknown         17448
# 8                       Unknown         16114
# 9                       Unknown         15567
#
#                          seen_last  ignore
# 0 2020-08-25 20:31:00.411425+00:00    True
# 1 2020-08-25 20:31:04.367238+00:00    True
# 2 2020-08-25 20:31:03.912872+00:00    True
# 3 2020-08-25 20:31:02.363234+00:00    True
# 4 2020-08-25 20:31:03.473862+00:00    True
# 5 2020-08-25 20:31:03.142937+00:00    True
# 6 2020-08-25 20:31:04.949261+00:00    True
# 7 2020-08-25 20:31:04.463635+00:00    True
# 8 2020-08-25 20:31:04.758116+00:00    True
# 9 2020-08-25 20:06:05.955396+00:00    True

# %%
# Same as above, but filter out all ignored devices
qs = Device.objects.filter(
    device_fingerprint__isnull=False,
    ignore=False,
    seen_last__gte=cut_off
).exclude(device_fingerprint__exact='').order_by('-seen_counter')[:10]

# Generate a Pandas dataframe
df = read_frame(qs, fieldnames=['device_fingerprint', 'device_manufacturer', 'seen_counter', 'seen_last', 'ignore'])
df
# Out:
#                                   device_fingerprint  \
# 0  fbfc713d50dce671f3457fd3292a81c62c53d9fc20666f...
# 1  df411ca9c811ca4182337f06c50280fbf027ac2d78b419...
# 2  5ad49becb9300d4b3dc5f9049b854a34f8e248a593e7df...
# 3  a7940b351d34aa220b4b87ae353baa8fe8ea8a710e9cc2...
# 4  4e568dd0e44e107f7c76737f144625068f54b9478677b6...
# 5  4956e0288b5a988f52472a5f523c7226f7b194f225d495...
# 6  bd9d780876aeb33cc0488d97557b66f0ea2e80c9cc27a7...
# 7  bd9d780876aeb33cc0488d97557b66f0ea2e80c9cc27a7...
# 8  a993d68352056ebbf8476d83ec32ac5197c53139f76d10...
# 9  7a7a62f899f7c6909e18b3ed3787593e23b39a4739264d...
#
#           device_manufacturer  seen_counter                        seen_last  \
# 0                     Unknown          3970 2020-08-25 20:31:03.730943+00:00
# 1                 Apple, Inc.          3110 2020-08-25 20:31:01.027257+00:00
# 2  Garmin International, Inc.          1804 2020-08-25 20:31:05.045730+00:00
# 3                     Unknown          1526 2020-08-23 06:16:03.745107+00:00
# 4                   IBM Corp.           773 2020-08-25 16:41:04.690743+00:00
# 5                 Apple, Inc.           738 2020-08-25 20:31:02.757238+00:00
# 6                 Apple, Inc.           723 2020-08-25 17:11:04.226179+00:00
# 7                 Apple, Inc.           620 2020-08-19 19:16:02.121111+00:00
# 8                     Unknown           573 2020-08-25 20:31:04.557527+00:00
# 9                     Unknown           541 2020-08-23 03:56:00.585138+00:00
#
#    ignore
# 0   False
# 1   False
# 2   False
# 3   False
# 4   False
# 5   False
# 6   False
# 7   False
# 8   False
# 9   False

# %%
# Get all devices with a device fingerprint, seen since the cut-off
qs = Device.objects.filter(
    device_fingerprint__isnull=False,
    seen_last__gte=cut_off
).exclude(device_fingerprint__exact='')

# Generate a Pandas dataframe
df = read_frame(qs, fieldnames=['device_fingerprint', 'device_manufacturer', 'seen_counter'])

# Visualize the result using Plotly
fig = px.bar(df, x="device_manufacturer", y="seen_counter", color="device_fingerprint")
fig.show()
# Out:
# <div>
#
#
#             <div id="3fbbd634-ba57-46d9-9a56-3d2d82c8531c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3fbbd634-ba57-46d9-9a56-3d2d82c8531c")) {
#                     Plotly.newPlot(
#                         '3fbbd634-ba57-46d9-9a56-3d2d82c8531c',
#                         [{"alignmentgroup": "True", "hovertemplate": "device_fingerprint=a465deac8c3afccdcc3ed004c986dd6042080b540366a64cd8dd83831abd3a78<br>device_manufacturer=%{x}<br>seen_counter=%{y}<extra></extra>", "legendgroup": "a465deac8c3afccdcc3ed004c986dd6042080b540366a64cd8dd83831abd3a78", "marker": {"color": "#636efa"}, "name": "a465deac8c3afccdcc3ed004c986dd6042080b540366a64cd8dd83831abd3a78", "offsetgroup": "a465deac8c3afccdcc3ed004c986dd6042080b540366a64cd8dd83831abd3a78", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Hewlett-Packard Company"], "xaxis": "x", "y": [10613], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "device_fingerprint=10a4c6538fe9037cae6bea5069e98240651922c21e78d831442b316009d7d6e0<br>device_manufacturer=%{x}<br>seen_counter=%{y}<extra></extra>", "legendgroup": "10a4c6538fe9037cae6bea5069e98240651922c21e78d831442b316009d7d6e0", "marker": {"color": "#EF553B"}, "name": "10a4c6538fe9037cae6bea5069e98240651922c21e78d831442b316009d7d6e0", "offsetgroup": "10a4c6538fe9037cae6bea5069e98240651922c21e78d831442b316009d7d6e0", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Samsung Electronics Co. Ltd."], "xaxis": "x", "y": [23183], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "device_fingerprint=fbfc713d50dce671f3457fd3292a81c62c53d9fc20666fb7cbb138068d0ed56c<br>device_manufacturer=%{x}<br>seen_counter=%{y}<extra></extra>", "legendgroup": "fbfc713d50dce671f3457fd3292a81c62c53d9fc20666fb7cbb138068d0ed56c", "marker": {"color": "#00cc96"}, "name": "fbfc713d50dce671f3457fd3292a81c62c53d9fc20666fb7cbb138068d0ed56c", "offsetgroup": "fbfc713d50dce671f3457fd3292a81c62c53d9fc20666fb7cbb138068d0ed56c", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Unknown", "Unknown", "Unknown", "Unknown", "Unknown", "Unknown"], "xaxis": "x", "y": [19376, 19819, 16112, 17446, 15567, 3968], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "device_fingerprint=4a3a3bd871e5b64359c3eef6bc2bd825a0f8c0c6eb659a5cf29d580bb98bb15f<br>device_manufacturer=%{x}<br>seen_counter=%{y}<extra></extra>", "legendgroup": "4a3a3bd871e5b64359c3eef6bc2bd825a0f8c0c6eb659a5cf29d580bb98bb15f", "marker": {"color": "#ab63fa"}, "name": "4a3a3bd871e5b64359c3eef6bc2bd825a0f8c0c6eb659a5cf29d580bb98bb15f", "offsetgroup": "4a3a3bd871e5b64359c3eef6bc2bd825a0f8c0c6eb659a5cf29d580bb98bb15f", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Unknown"], "xaxis": "x", "y": [22269], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "device_fingerprint=18603d972672e85a314f83b5cbfcd1faf83281949ae94b8efd6442fa03d9e3bd<br>device_manufacturer=%{x}<br>seen_counter=%{y}<extra></extra>", "legendgroup": "18603d972672e85a314f83b5cbfcd1faf83281949ae94b8efd6442fa03d9e3bd", "marker": {"color": "#FFA15A"}, "name": "18603d972672e85a314f83b5cbfcd1faf83281949ae94b8efd6442fa03d9e3bd", "offsetgroup": "18603d972672e85a314f83b5cbfcd1faf83281949ae94b8efd6442fa03d9e3bd", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Unknown"], "xaxis": "x", "y": [7333], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "device_fingerprint=42b04e17dc95e7ae86987795f23b553d2a2104aa57c8dc2429546d04b19d7fee<br>device_manufacturer=%{x}<br>seen_counter=%{y}<extra></extra>", "legendgroup": "42b04e17dc95e7ae86987795f23b553d2a2104aa57c8dc2429546d04b19d7fee", "marker": {"color": "#19d3f3"}, "name": "42b04e17dc95e7ae86987795f23b553d2a2104aa57c8dc2429546d04b19d7fee", "offsetgroup": "42b04e17dc95e7ae86987795f23b553d2a2104aa57c8dc2429546d04b19d7fee", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Samsung Electronics Co. Ltd."], "xaxis": "x", "y": [22364], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "device_fingerprint=df411ca9c811ca4182337f06c50280fbf027ac2d78b41993895f75b867e416fd<br>device_manufacturer=%{x}<br>seen_counter=%{ ...
